# %% [markdown]
# # Homework #4
# #### Aidan Berres
# #### Physics 434
# #### 10/29/20

# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy
from scipy import stats
import sympy as sp

# %% [markdown]
# ## Problem 0: some fake data to mess with

# %%
t = np.linspace(0,np.pi*100,np.int(1e5))
N = 10+np.sin(t)
bkgd = stats.norm.rvs(size=np.int(1e5))*np.sqrt(N)+N

# %% [markdown]
# ## Problem 1: subsets of data

# %%
fig, ax = plt.subplots(1,1,figsize=(11.5,8))
x1=np.arange(1000)
ax.scatter(x1,bkgd[:1000]);

# %%
def xandy(x,y):
    if x+y>len(bkgd):
        print('WRONG!')
        return
    else:
        bs=bkgd[y:x+y]
        return bs

# %%
fig, ax = plt.subplots(1,1,figsize=(11.5,8))
bs=xandy(2000,500)
x2=np.arange(len(bs))
ax.scatter(x2,bs);

# %%
#1c
i=100
hunnid=[]
while i<int(1e5):
    hunnid.append(bkgd[i])
    i=i+100

# %%
fig, ax = plt.subplots(1,1,figsize=(11.5,8))
x3=np.arange(len(hunnid))
ax.scatter(x3,hunnid);

# %% [markdown]
# ## Problem 2: density

# %%
fig, ax = plt.subplots(1,1,figsize=(11,10))
xd=stats.norm.rvs(size=np.int(1e5),random_state=420)
yd=stats.norm.rvs(size=np.int(1e5),random_state=69)
d=ax.hist2d(xd,yd,bins=50)
fig.colorbar(d[3]);

# %%
fig, ax = plt.subplots(1,1,figsize=(11,10))
x4=np.arange(len(bkgd))
ax.hist2d(x4,bkgd,bins=50);

# %% [markdown]
# ## 2. b)

# %% [markdown]
# ## Problem 3: folding

# %%
t = np.linspace(0,np.pi*100,np.int(1e5)) % (2*np.pi)
N = 10+np.sin(t)
bkgdm = stats.norm.rvs(size=np.int(1e5))*np.sqrt(N)+N

# %%
fig, ax = plt.subplots(1,1,figsize=(11.5,8))
x1=np.arange(1000)
ax.scatter(x1,bkgdm[:1000]);
